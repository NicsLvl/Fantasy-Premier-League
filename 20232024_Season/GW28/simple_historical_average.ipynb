# %% [markdown]
# # Current Data

# %%
import requests
import pandas as pd
import json
import plotly.express as px

# %% [markdown]
# ## Todo list
# - Only data from current season for now, model is limited at the start of a new season -> a new model has to be developed that uses weighted historical data
# - Just use points per minute against cost for now
# - Ignores current match fixture difficulty for now
# - Evaluates players that have more than 0% chance to play for now -> there should be a classification model to determine who coaches will pick in the starting line up
# - Investigate data anomalies that can skew calculations
# - Come up with accuracy prediction evaluations each week
# - Consider set piece takers

# %%
GAMEWEEK = 28

# Have to run this before they update the data each week
url = "https://fantasy.premierleague.com/api/bootstrap-static/"
response = requests.get(url)
general_data = response.json()
players = general_data['elements']
players = [x for x in players if x['chance_of_playing_next_round'] == 100]
# players = [x for x in players if x['chance_of_playing_this_round'] != 0 and x['chance_of_playing_this_round'] != None]
players = [x['id'] for x in players]
print(f"{len(players)} players have a chance to play in week {GAMEWEEK}")
print("")

url = "https://fantasy.premierleague.com/api/fixtures/"
response = requests.get(url)
fixture_data = response.json()
fixture_data = [x for x in fixture_data if x['event'] == GAMEWEEK]
print("1 is easy fixture, 5 is difficult fixture")
for i in range(len(fixture_data)):
    fixture_data[i]['team_a'] = general_data['teams'][fixture_data[i]['team_a']-1]['name']
    fixture_data[i]['team_h'] = general_data['teams'][fixture_data[i]['team_h']-1]['name']
    print(f"{fixture_data[i]['team_h']}, {fixture_data[i]['team_h_difficulty']} vs {fixture_data[i]['team_a']}, {fixture_data[i]['team_a_difficulty']}, {fixture_data[i]['kickoff_time']}")

historical = pd.DataFrame()
for i in range(GAMEWEEK-1):
    url = f"https://fantasy.premierleague.com/api/event/{i+1}/live/"
    response = requests.get(url)
    live_data = response.json()
    live_data = live_data['elements']
    live_df = pd.DataFrame(live_data)
    live_df = live_df[['stats']]
    live_df = pd.json_normalize(live_df['stats']).reset_index()
    live_df = live_df[live_df['index'].isin(players)]
    historical = pd.concat([historical, live_df], ignore_index=True)

print(historical.head())
# Out:
# 300 players have a chance to play in week 28
#
# 1 is easy fixture, 5 is difficult fixture
# Man Utd, 2 vs Everton, 4, 2024-03-09T12:30:00Z
# Bournemouth, 2 vs Sheffield Utd, 2, 2024-03-09T15:00:00Z
# Crystal Palace, 2 vs Luton, 2, 2024-03-09T15:00:00Z
# Wolves, 2 vs Fulham, 2, 2024-03-09T15:00:00Z
# Arsenal, 2 vs Brentford, 5, 2024-03-09T17:30:00Z
# Aston Villa, 3 vs Spurs, 4, 2024-03-10T13:00:00Z
# Brighton, 2 vs Nott'm Forest, 3, 2024-03-10T14:00:00Z
# West Ham, 2 vs Burnley, 3, 2024-03-10T14:00:00Z
# Liverpool, 5 vs Man City, 5, 2024-03-10T15:45:00Z
# Chelsea, 3 vs Newcastle, 3, 2024-03-11T20:00:00Z
# Bournemouth, 2 vs Luton, 2, 2024-03-13T19:30:00Z
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 27
#      25 for i in range(GAMEWEEK-1):
#      26     url = f"https://fantasy.premierleague.com/api/event/{i+1}/live/"
# ---> 27     response = requests.get(url)
#      28     live_data = response.json()
#      29     live_data = live_data['elements']
#
# File c:\Users\hurry\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File c:\Users\hurry\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File c:\Users\hurry\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File c:\Users\hurry\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File c:\Users\hurry\AppData\Local\Programs\Python\Python312\Lib\site-packages\requests\adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File c:\Users\hurry\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File c:\Users\hurry\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:468, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     465 try:
#     466     # Trigger any extra validation we need to do.
#     467     try:
# --> 468         self._validate_conn(conn)
#     469     except (SocketTimeout, BaseSSLError) as e:
#     470         self._raise_timeout(err=e, url=url, timeout_value=conn.timeout)
#
# File c:\Users\hurry\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connectionpool.py:1097, in HTTPSConnectionPool._validate_conn(self, conn)
#    1095 # Force connect early to allow us to validate the connection.
#    1096 if conn.is_closed:
# -> 1097     conn.connect()
#    1099 if not conn.is_verified:
#    1100     warnings.warn(
#    1101         (
#    1102             f"Unverified HTTPS request is being made to host '{conn.host}'. "
#    (...)
#    1107         InsecureRequestWarning,
#    1108     )
#
# File c:\Users\hurry\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:642, in HTTPSConnection.connect(self)
#     633 if is_time_off:
#     634     warnings.warn(
#     635         (
#     636             f"System time is way off (before {RECENT_DATE}). This will probably "
#    (...)
#     639         SystemTimeWarning,
#     640     )
# --> 642 sock_and_verified = _ssl_wrap_socket_and_match_hostname(
#     643     sock=sock,
#     644     cert_reqs=self.cert_reqs,
#     645     ssl_version=self.ssl_version,
#     646     ssl_minimum_version=self.ssl_minimum_version,
#     647     ssl_maximum_version=self.ssl_maximum_version,
#     648     ca_certs=self.ca_certs,
#     649     ca_cert_dir=self.ca_cert_dir,
#     650     ca_cert_data=self.ca_cert_data,
#     651     cert_file=self.cert_file,
#     652     key_file=self.key_file,
#     653     key_password=self.key_password,
#     654     server_hostname=server_hostname,
#     655     ssl_context=self.ssl_context,
#     656     tls_in_tls=tls_in_tls,
#     657     assert_hostname=self.assert_hostname,
#     658     assert_fingerprint=self.assert_fingerprint,
#     659 )
#     660 self.sock = sock_and_verified.socket
#     661 self.is_verified = sock_and_verified.is_verified
#
# File c:\Users\hurry\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\connection.py:783, in _ssl_wrap_socket_and_match_hostname(sock, cert_reqs, ssl_version, ssl_minimum_version, ssl_maximum_version, cert_file, key_file, key_password, ca_certs, ca_cert_dir, ca_cert_data, assert_hostname, assert_fingerprint, server_hostname, ssl_context, tls_in_tls)
#     780     if is_ipaddress(normalized):
#     781         server_hostname = normalized
# --> 783 ssl_sock = ssl_wrap_socket(
#     784     sock=sock,
#     785     keyfile=key_file,
#     786     certfile=cert_file,
#     787     key_password=key_password,
#     788     ca_certs=ca_certs,
#     789     ca_cert_dir=ca_cert_dir,
#     790     ca_cert_data=ca_cert_data,
#     791     server_hostname=server_hostname,
#     792     ssl_context=context,
#     793     tls_in_tls=tls_in_tls,
#     794 )
#     796 try:
#     797     if assert_fingerprint:
#
# File c:\Users\hurry\AppData\Local\Programs\Python\Python312\Lib\site-packages\urllib3\util\ssl_.py:446, in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     444 if ca_certs or ca_cert_dir or ca_cert_data:
#     445     try:
# --> 446         context.load_verify_locations(ca_certs, ca_cert_dir, ca_cert_data)
#     447     except OSError as e:
#     448         raise SSLError(e) from e
#
# KeyboardInterrupt:

# %%
print(historical.columns)
# Out:
# Index(['index', 'minutes', 'goals_scored', 'assists', 'clean_sheets',
#        'goals_conceded', 'own_goals', 'penalties_saved', 'penalties_missed',
#        'yellow_cards', 'red_cards', 'saves', 'bonus', 'bps', 'influence',
#        'creativity', 'threat', 'ict_index', 'starts', 'expected_goals',
#        'expected_assists', 'expected_goal_involvements',
#        'expected_goals_conceded', 'total_points', 'in_dreamteam'],
#       dtype='object')

# %%
eval = historical.groupby(['index'])[['minutes', 'total_points']].sum()
# select players who at least have a historical record
eval = eval[eval['minutes'] > 0]
# select players who at least are positive overall
eval = eval[eval['total_points'] > 0]
print(f"We will pick from a pool of {len(eval)}")

# for each index, get the player name
for i in eval.index:
    # search the id in general data and pull the name
    for j in range(len(general_data['elements'])):
        if general_data['elements'][j]['id'] == i:
            eval.loc[i, 'ppg'] = general_data['elements'][j]['points_per_game']
            eval.loc[i, 'cost'] = general_data['elements'][j]['now_cost']
            eval.loc[i, 'first_name'] = general_data['elements'][j]['first_name']
            eval.loc[i, 'second_name'] = general_data['elements'][j]['second_name']
            eval.loc[i, 'team'] = general_data['teams'][general_data['elements'][j]['team']-1]['name']
            eval.loc[i, 'position'] = general_data['elements'][j]['element_type']
            eval.loc[i, 'news'] = general_data['elements'][j]['news']
            eval.loc[i, 'news_added'] = general_data['elements'][j]['news_added']
            eval.loc[i, 'expected_points'] = general_data['elements'][j]['ep_next']
            break

eval['name'] = eval['first_name'] + " " + eval['second_name']
eval['ppm'] = eval['total_points'] / eval['minutes']
eval['ppmcost'] = eval['ppm'] / eval['cost'] * 1000
eval['ppg'] = eval['ppg'].astype(float)
eval = eval.sort_values(by='ppmcost', ascending=False)
eval['position'] = eval['position'].map({1: 'GK', 2: 'DEF', 3: 'MID', 4: 'FWD'})
eval = eval[['name', 'team', 'position', 'cost', 'expected_points','ppg', 'ppm', 'ppmcost', 'minutes', 'total_points', 'news', 'news_added']]

print(eval.describe())
# Out:
# We will pick from a pool of 200
#              cost         ppg         ppm     ppmcost      minutes  \
# count  200.000000  200.000000  200.000000  200.000000   200.000000
# mean    51.385000    2.461000    0.059693    1.200705  1042.240000
# std     13.012818    1.364142    0.085004    1.728465   745.589398
# min     38.000000    0.000000    0.002075    0.051867     1.000000
# 25%     44.000000    1.400000    0.030193    0.601504   382.250000
# 50%     49.000000    2.500000    0.042197    0.845286   981.000000
# 75%     54.000000    3.300000    0.059389    1.190360  1707.000000
# max    144.000000    8.200000    1.000000   20.000000  2430.000000
#
#        total_points
# count    200.000000
# mean      43.310000
# std       35.181424
# min        1.000000
# 25%       14.000000
# 50%       34.000000
# 75%       66.000000
# max      167.000000

# %%
# print top expected points
print(eval.sort_values(by='expected_points', ascending=False).head(20))
# Out:
#                                   name           team position   cost  \
# index
# 77                Norberto Murara Neto    Bournemouth       GK   47.0
# 279             Rodrigo Muniz Carvalho         Fulham      FWD   45.0
# 43        Douglas Luiz Soares de Paulo    Aston Villa      MID   57.0
# 526                       Jarrod Bowen       West Ham      MID   79.0
# 20                      William Saliba        Arsenal      DEF   58.0
# 5         Gabriel dos Santos Magalhães        Arsenal      DEF   53.0
# 355                     Erling Haaland       Man City      FWD  144.0
# 134                        Pascal Groß       Brighton      MID   66.0
# 352          Ederson Santana de Moraes       Man City       GK   55.0
# 365                  Rodrigo Hernandez       Man City      MID   56.0
# 26                    Leandro Trossard        Arsenal      MID   65.0
# 406    Bruno Guimarães Rodriguez Moura      Newcastle      MID   58.0
# 205                 Callum Hudson-Odoi  Nott'm Forest      MID   47.0
# 304                Alexis Mac Allister      Liverpool      MID   58.0
# 303                          Luis Díaz      Liverpool      MID   75.0
# 427                       Fabian Schär      Newcastle      DEF   54.0
# 129                         Lewis Dunk       Brighton      DEF   52.0
# 595                       Milos Kerkez    Bournemouth      DEF   44.0
# 450                    Brennan Johnson          Spurs      MID   58.0
# 84                          Adam Smith    Bournemouth      DEF   44.0
#
#       expected_points  ppg       ppm   ppmcost  minutes  total_points news  \
# index
# 77                8.6  3.8  0.039924  0.849446      526            21
# 279               8.5  3.6  0.034128  0.758397     1846            63
# 43                7.8  5.2  0.137931  2.419843      174            24
# 526               7.7  5.6  0.106796  1.351850      103            11
# 20                7.5  4.1  0.032037  0.552355      874            28
# 5                 7.5  4.1  0.061200  1.154721     1683           103
# 355               7.3  6.9  0.034043  0.236407      940            32
# 134               6.5  5.0  0.059928  0.907997     1385            83
# 352               6.3  3.3  0.071171  1.294021     2220           158
# 365               6.3  4.5  0.333333  5.952381       18             6
# 26                6.2  3.7  0.011905  0.183150     1680            20
# 406               6.2  3.4  0.041548  0.716346     1757            73
# 205               6.0  3.7  0.023316  0.496086      386             9
# 304               5.7  2.9  0.026958  0.464787      779            21
# 303               5.5  3.8  0.037188  0.495836     1721            64
# 427               5.5  3.6  0.025974  0.481000       77             2
# 129               5.5  2.6  0.076923  1.479290      130            10
# 595               5.4  2.1  0.028395  0.645342     2430            69
# 450               5.3  3.5  0.049751  0.857780      201            10
# 84                5.0  2.6  0.056156  1.276262     2315           130
#
#                         news_added
# index
# 77     2023-10-27T13:30:07.907911Z
# 279    2023-11-04T15:30:08.544057Z
# 43     2023-12-09T20:00:09.137355Z
# 526    2024-01-07T21:30:10.877600Z
# 20     2023-10-09T08:30:07.861646Z
# 5      2024-01-20T15:30:09.437664Z
# 355    2023-12-10T18:00:10.148960Z
# 134    2023-09-22T14:00:07.601244Z
# 352    2024-01-13T22:30:10.940316Z
# 365    2023-12-23T22:30:09.724645Z
# 26     2023-10-09T08:30:07.911344Z
# 406    2023-11-04T21:00:09.029195Z
# 205    2024-02-05T08:30:09.357556Z
# 304    2024-01-29T06:30:09.385993Z
# 303    2023-12-23T22:00:09.137690Z
# 427    2024-02-17T19:00:09.641548Z
# 129    2023-12-28T22:00:09.818659Z
# 595    2023-12-21T15:00:10.669352Z
# 450    2023-12-16T08:00:10.122072Z
# 84     2024-01-22T01:00:09.769539Z

# %%
# Manual Fixes

# eval = eval[eval['team'] != 'Liverpool']
# eval = eval[eval['team'] != 'Man City']
# eval = eval[eval['team'] != 'Man Utd']
# eval = eval[eval['team'] != 'Chelsea']
# eval = eval[eval['team'] != 'Arsernal']
# eval = eval[eval['team'] != 'Crystal Palace']
# eval = eval[eval['team'] != 'Wolves']
# eval = eval[eval['team'] != 'Bournemouth']
# eval = eval[eval['team'] != 'Brighton']
# eval = eval[eval['team'] != 'Newcastle']
# eval = eval[eval['team'] != 'Sheffield Utd']
# eval = eval[eval['team'] != 'Wolves']

# %%
# select players who play alot for more consistency, try to aim for 50 players to select from
# create a deep copy of eval
ppmcost = eval.copy(deep=True)
min_thres = 1450
cost_thres = 0.5
ppmcost = ppmcost[ppmcost['minutes'] > min_thres]
ppmcost = ppmcost[ppmcost['ppmcost'] > cost_thres]
print(f"{len(ppmcost)} players have played more than {min_thres} minutes and {cost_thres} and selected for ppmcost algo")

fig = px.scatter(ppmcost, x='minutes', y='ppmcost', hover_data=[
                 'name', 'team', 'position'], title='Minutes vs PPMCost', color='position')
fig.show()

# We can only max 3 players from each team
team_count = {'Spurs': 0,
              "Nott'm Forest": 0,
              'Liverpool': 0,
              'Bournemouth': 0,
              'Aston Villa': 0,
              'Man City': 0,
              'Arsenal': 0,
              'Crystal Palace': 0,
              'Man Utd': 0,
              'Fulham': 0,
              'Luton': 0,
              'Everton': 0,
              'Brentford': 0,
              'Newcastle': 0,
              'Wolves': 0,
              'West Ham': 0,
              'Chelsea': 0,
              'Sheffield Utd': 0,
              'Brighton': 0,
              'Burnley': 0, }

team_count = dict(sorted(team_count.items()))

# ppmcost algo
# select 11 players from eval
# first select the top GK
# then select the top FWD
# then select the top 3 DEF
# then select 6 more players up to 2 more DEF, 5 MID and 2 more FWD

# select the top GK
gk = ppmcost[ppmcost['position'] == 'GK'].sort_values(
    by='ppmcost', ascending=False).head(1)
ppmcost = ppmcost[~ppmcost.index.isin(gk.index)]
gk_count = 1
team_count[gk['team'].values[0]] += 1

# select the top FWD
fwd = ppmcost[ppmcost['position'] == 'FWD'].sort_values(
    by='ppmcost', ascending=False).head(1)
fwd_count = 1
team_count[fwd['team'].values[0]] += 1
ppmcost = ppmcost[~ppmcost.index.isin(fwd.index)]

selected_11 = pd.concat([gk, fwd])

# select the top 3 DEF
defe = ppmcost[ppmcost['position'] == 'DEF'].sort_values(
    by='ppmcost', ascending=False)
def_count = 0
for i in defe.index:
    # check if any team has more than 3 players
    if team_count[defe.loc[i, 'team']] > 3:
        continue
    else:
        selected_11 = pd.concat(
            [selected_11, defe.loc[i, :].to_frame().T])
        def_count += 1
        team_count[defe.loc[i, 'team']] += 1
        ppmcost = ppmcost[~ppmcost.index.isin([i])]
        if def_count == 3:
            break
        else:
            continue

mid_count = 0

def select_6():
    global ppmcost, gk_count, def_count, fwd_count, mid_count, team_count
    ppmcost = ppmcost.sort_values(by='ppmcost', ascending=False)
    selected_6 = pd.DataFrame()
    for i in ppmcost.index:
        if ppmcost.loc[i, 'position'] == 'DEF' and def_count < 5:
            # concat the player row to the selected_6 dataframe
            selected_6 = pd.concat(
                [selected_6, ppmcost.loc[i, :].to_frame().T])
            def_count += 1
            team_count[ppmcost.loc[i, 'team']] += 1
        elif ppmcost.loc[i, 'position'] == 'MID' and mid_count < 5:
            selected_6 = pd.concat(
                [selected_6, ppmcost.loc[i, :].to_frame().T])
            mid_count += 1
            team_count[ppmcost.loc[i, 'team']] += 1
        elif ppmcost.loc[i, 'position'] == 'FWD' and fwd_count < 3:
            selected_6 = pd.concat(
                [selected_6, ppmcost.loc[i, :].to_frame().T])
            fwd_count += 1
            team_count[ppmcost.loc[i, 'team']] += 1
        elif ppmcost.loc[i, 'position'] == 'GK' and gk_count < 1:
            selected_6 = pd.concat(
                [selected_6, ppmcost.loc[i, :].to_frame().T])
            gk_count += 1
            team_count[ppmcost.loc[i, 'team']] += 1
        else:
            continue
        if gk_count + def_count + fwd_count + mid_count == 11:
            print(f"Final Selection: {gk_count} GK, {
                  def_count} DEF, {fwd_count} FWD, {mid_count} MID")
            print("")
            return selected_6


selected_6 = select_6()
selected_11 = pd.concat([selected_6, selected_11])

# Assume 4m from bench of 4 players
BUDGET = 840
print(team_count)
print("")
print(f"Current budget spent: {selected_11['cost'].sum()}, remaining budget: {
      BUDGET - selected_11['cost'].sum()}")
print("")
print(selected_11)
# Out:
# 57 players have played more than 1450 minutes and 0.5 and selected for ppmcost algo
# Final Selection: 1 GK, 5 DEF, 2 FWD, 3 MID
#
# {'Arsenal': 2, 'Aston Villa': 1, 'Bournemouth': 1, 'Brentford': 0, 'Brighton': 0, 'Burnley': 0, 'Chelsea': 0, 'Crystal Palace': 0, 'Everton': 0, 'Fulham': 1, 'Liverpool': 1, 'Luton': 1, 'Man City': 2, 'Man Utd': 0, 'Newcastle': 0, "Nott'm Forest": 0, 'Sheffield Utd': 0, 'Spurs': 1, 'West Ham': 1, 'Wolves': 0}
#
# Current budget spent: 548.0, remaining budget: 292.0
#
#                              name         team position  cost expected_points  \
# 515                  Oliver Skipp        Spurs      MID  45.0             0.0
# 342                    Nathan Aké     Man City      DEF  51.0             4.7
# 5    Gabriel dos Santos Magalhães      Arsenal      DEF  53.0             7.5
# 364               Kalvin Phillips     West Ham      MID  47.0             0.5
# 662                  Adama Traoré       Fulham      MID  49.0             2.8
# 340                Cauley Woodrow        Luton      FWD  43.0             0.0
# 352     Ederson Santana de Moraes     Man City       GK  55.0             6.3
# 13                  Eddie Nketiah      Arsenal      FWD  51.0             1.8
# 307              Andrew Robertson    Liverpool      DEF  64.0             1.5
# 42                    Lucas Digne  Aston Villa      DEF  46.0             2.5
# 84                     Adam Smith  Bournemouth      DEF  44.0             5.0
#
#      ppg       ppm   ppmcost minutes total_points news  \
# 515  1.1  0.078545  1.745446    1897          149
# 342  3.6   0.06015  1.179419    2128          128
# 5    4.1    0.0612  1.154721    1683          103
# 364  0.8  0.052023  1.106875    2076          108
# 662  1.9  0.049847  1.017285    2287          114
# 340  0.9  0.043478  1.011122    1587           69
# 352  3.3  0.071171  1.294021    2220          158
# 13   2.8  0.059322  1.163177    2124          126
# 307  2.5  0.093505  1.461016    1786          167
# 42   3.0  0.059875  1.301628    2238          134
# 84   2.6  0.056156  1.276262    2315          130
#
#                       news_added
# 515  2023-12-28T23:30:10.167224Z
# 342  2023-11-13T01:00:09.634159Z
# 5    2024-01-20T15:30:09.437664Z
# 364  2024-02-17T18:00:08.287738Z
# 662  2023-11-24T22:00:11.972817Z
# 340  2023-11-10T17:30:09.674003Z
# 352  2024-01-13T22:30:10.940316Z
# 13   2023-11-09T08:30:08.250179Z
# 307  2024-03-01T13:00:10.035871Z
# 42   2023-12-27T18:30:08.720986Z
# 84   2024-01-22T01:00:09.769539Z

# %%
# If there is still budget, excecute the maximise pointsperminute algo

# Maximise points per minute
# Sort Eval by ppm
# Substitute the lowest ppmcost player with the highest ppm player if it already does not exist
# If the player already exists, then substitute with the next highest ppm player
ppm = eval.copy(deep=True)
min_thres = 1450
ppm = ppm[ppm['minutes'] > min_thres]
ppm = ppm.sort_values(by=['ppm','ppmcost'], ascending=False)
ppm = ppm[~ppm.index.isin(selected_11.index)]
print(f"{len(ppm)} players have played more than {min_thres} minutes and selected for ppm algo")

def substitute_for_points():
    global ppm, selected_11, team_count, gk_count, def_count, fwd_count, mid_count
    selected_11 = selected_11.sort_values(by=['ppm', 'ppmcost'], ascending=True)
    # print(selected_11)

    # Substitute the lowest ppm player
    for i in selected_11.index:
        if selected_11.loc[i, 'position'] == 'GK':
            gk_count -= 1
        elif selected_11.loc[i, 'position'] == 'DEF':
            def_count -= 1
        elif selected_11.loc[i, 'position'] == 'MID':
            mid_count -= 1
        elif selected_11.loc[i, 'position'] == 'FWD':
            fwd_count -= 1
        # remove the count from team_count
        team_count[selected_11.loc[i, 'team']] -= 1
        # print(f"Substituting: {selected_11.loc[i, ['name','ppm']]}")

        # Find the highest possible ppm player
        for j in ppm.index:
            sub = False
            if selected_11.loc[i, 'ppm'] > ppm.loc[j, 'ppm']:
                pass
            elif team_count[ppm.loc[j, 'team']] > 2:
                pass
            elif ppm.loc[j, 'cost'] + selected_11['cost'].sum() > BUDGET+20:
                pass
            elif ppm.loc[j, 'position'] == 'GK' and gk_count > 0:
                pass
            elif ppm.loc[j, 'position'] == 'DEF' and def_count > 4:
                pass
            elif ppm.loc[j, 'position'] == 'MID' and mid_count > 4:
                pass
            elif ppm.loc[j, 'position'] == 'FWD' and fwd_count > 2:
                pass
            else:
                # remove the player from selected_11
                sub = True
                print(f"Substituted: {selected_11.loc[i,['name','ppm']].values} for  {ppm.loc[j, ['name','ppm']].values}")
                selected_11 = selected_11[~selected_11.index.isin([i])]
                selected_11 = pd.concat([selected_11, ppm.loc[j, :].to_frame().T])
                selected_11 = selected_11.sort_values(by=['ppm', 'ppmcost'], ascending=True)
                team_count[ppm.loc[j, 'team']] += 1
                if ppm.loc[j, 'position'] == 'GK':
                    gk_count += 1
                elif ppm.loc[j, 'position'] == 'DEF':
                    def_count += 1
                elif ppm.loc[j, 'position'] == 'MID':
                    mid_count += 1
                elif ppm.loc[j, 'position'] == 'FWD':
                    fwd_count += 1
                ppm = ppm[~ppm.index.isin([j])]
                break
        if sub == False:
            if selected_11.loc[i, 'position'] == 'GK':
                gk_count += 1
            elif selected_11.loc[i, 'position'] == 'DEF':
                def_count += 1
            elif selected_11.loc[i, 'position'] == 'MID':
                mid_count += 1
            elif selected_11.loc[i, 'position'] == 'FWD':
                fwd_count += 1
            team_count[selected_11.loc[i, 'team']] += 1
        if selected_11['cost'].sum() > BUDGET:
            print("budget reached")
            break
     
    return selected_11

selected_11 = substitute_for_points()
print(f"Final Selection: {gk_count} GK, {def_count} DEF, {fwd_count} FWD, {mid_count} MID")
print(f"Current budget spent: {selected_11['cost'].sum()}, remaining budget: {BUDGET - selected_11['cost'].sum()}")
print(team_count)
print("")
print(selected_11)
# Out:
# 54 players have played more than 1450 minutes and selected for ppm algo
# Substituted: ['Cauley Woodrow' 0.043478260869565216] for  ['Mohamed Salah' 0.049611476389719064]
# Final Selection: 1 GK, 5 DEF, 1 FWD, 4 MID
# Current budget spent: 635.0, remaining budget: 205.0
# {'Arsenal': 2, 'Aston Villa': 1, 'Bournemouth': 1, 'Brentford': 0, 'Brighton': 0, 'Burnley': 0, 'Chelsea': 0, 'Crystal Palace': 0, 'Everton': 0, 'Fulham': 1, 'Liverpool': 2, 'Luton': 0, 'Man City': 2, 'Man Utd': 0, 'Newcastle': 0, "Nott'm Forest": 0, 'Sheffield Utd': 0, 'Spurs': 1, 'West Ham': 1, 'Wolves': 0}
#
#                              name         team position   cost  \
# 308                 Mohamed Salah    Liverpool      MID  130.0
# 662                  Adama Traoré       Fulham      MID   49.0
# 364               Kalvin Phillips     West Ham      MID   47.0
# 84                     Adam Smith  Bournemouth      DEF   44.0
# 13                  Eddie Nketiah      Arsenal      FWD   51.0
# 42                    Lucas Digne  Aston Villa      DEF   46.0
# 342                    Nathan Aké     Man City      DEF   51.0
# 5    Gabriel dos Santos Magalhães      Arsenal      DEF   53.0
# 352     Ederson Santana de Moraes     Man City       GK   55.0
# 515                  Oliver Skipp        Spurs      MID   45.0
# 307              Andrew Robertson    Liverpool      DEF   64.0
#
#     expected_points  ppg       ppm   ppmcost minutes total_points news  \
# 308             2.3  8.0  0.049611  0.381627    1673           83
# 662             2.8  1.9  0.049847  1.017285    2287          114
# 364             0.5  0.8  0.052023  1.106875    2076          108
# 84              5.0  2.6  0.056156  1.276262    2315          130
# 13              1.8  2.8  0.059322  1.163177    2124          126
# 42              2.5  3.0  0.059875  1.301628    2238          134
# 342             4.7  3.6   0.06015  1.179419    2128          128
# 5               7.5  4.1    0.0612  1.154721    1683          103
# 352             6.3  3.3  0.071171  1.294021    2220          158
# 515             0.0  1.1  0.078545  1.745446    1897          149
# 307             1.5  2.5  0.093505  1.461016    1786          167
#
#                       news_added
# 308  2024-02-26T00:30:09.476744Z
# 662  2023-11-24T22:00:11.972817Z
# 364  2024-02-17T18:00:08.287738Z
# 84   2024-01-22T01:00:09.769539Z
# 13   2023-11-09T08:30:08.250179Z
# 42   2023-12-27T18:30:08.720986Z
# 342  2023-11-13T01:00:09.634159Z
# 5    2024-01-20T15:30:09.437664Z
# 352  2024-01-13T22:30:10.940316Z
# 515  2023-12-28T23:30:10.167224Z
# 307  2024-03-01T13:00:10.035871Z

# %%
# If there is still budget, excecute the maximise pointspergame algo

# Maximise points per game
# Sort Eval by ppg
# Substitute the lowest ppg player with the highest ppg player if it already does not exist
ppg = eval.copy(deep=True)
minutes_threshold = 1450
ppg = ppg[ppg['minutes'] > minutes_threshold]
ppg = ppg.sort_values(by='ppg', ascending=False)
ppg = ppg[~ppg.index.isin(selected_11.index)]
print(f"{len(ppg)} players have played more than {minutes_threshold} minutes and selected for ppg algo")

def substitute_for_points():
    global ppg, selected_11, team_count, gk_count, def_count, fwd_count, mid_count
    selected_11 = selected_11.sort_values(by=['ppg', 'ppm', 'ppmcost'], ascending=True)
    # print(selected_11)

    # Substitute the lowest ppg player
    for i in selected_11.index:
        if selected_11.loc[i, 'position'] == 'GK':
            gk_count -= 1
        elif selected_11.loc[i, 'position'] == 'DEF':
            def_count -= 1
        elif selected_11.loc[i, 'position'] == 'MID':
            mid_count -= 1
        elif selected_11.loc[i, 'position'] == 'FWD':
            fwd_count -= 1
        team_count[selected_11.loc[i, 'team']] -= 1

        # Find the highest possible ppg player
        for j in ppg.index:
            sub = False
            if selected_11.loc[i, 'ppg'] > ppg.loc[j, 'ppg']:
                pass
            elif team_count[ppg.loc[j, 'team']] > 2:
                pass
            elif ppg.loc[j, 'cost'] + selected_11['cost'].sum() > BUDGET+20:
                pass
            elif ppg.loc[j, 'position'] == 'GK' and gk_count > 0:
                pass
            elif ppg.loc[j, 'position'] == 'DEF' and def_count > 4:
                pass
            elif ppg.loc[j, 'position'] == 'MID' and mid_count > 4:
                pass
            elif ppg.loc[j, 'position'] == 'FWD' and fwd_count > 2:
                pass
            else:
                # remove the player from selected_11
                sub = True
                print(f"Substituted: {selected_11.loc[i,['name','ppg']].values} for  {ppg.loc[j, ['name','ppg']].values}")
                selected_11 = selected_11[~selected_11.index.isin([i])]
                selected_11 = pd.concat([selected_11, ppg.loc[j, :].to_frame().T])
                selected_11 = selected_11.sort_values(by=['ppg', 'ppm', 'ppmcost'], ascending=True)
                team_count[ppg.loc[j, 'team']] += 1
                if ppg.loc[j, 'position'] == 'GK':
                    gk_count += 1
                elif ppg.loc[j, 'position'] == 'DEF':
                    def_count += 1
                elif ppg.loc[j, 'position'] == 'MID':
                    mid_count += 1
                elif ppg.loc[j, 'position'] == 'FWD':
                    fwd_count += 1
                ppg = ppg[~ppg.index.isin([j])]
                break
        if sub == False:
            if selected_11.loc[i, 'position'] == 'GK':
                gk_count += 1
            elif selected_11.loc[i, 'position'] == 'DEF':
                def_count += 1
            elif selected_11.loc[i, 'position'] == 'MID':
                mid_count += 1
            elif selected_11.loc[i, 'position'] == 'FWD':
                fwd_count += 1
            team_count[selected_11.loc[i, 'team']] += 1
        if selected_11['cost'].sum() > BUDGET:
            print("budget reached")
            break
     
    return selected_11

selected_11 = substitute_for_points()
print(f"Final Selection: {gk_count} GK, {def_count} DEF, {fwd_count} FWD, {mid_count} MID")
print(f"Current budget spent: {selected_11['cost'].sum()}, remaining budget: {BUDGET - selected_11['cost'].sum()}")
print(team_count)
print("")
print(selected_11)
# Out:
# 54 players have played more than 1450 minutes and selected for ppg algo
# Substituted: ['Milos Kerkez' 2.1] for  ['Mohamed Salah' 8.0]
# Substituted: ['Ryan Christie' 2.2] for  ['Dominic Solanke' 5.0]
# Substituted: ['Adam Smith' 2.6] for  ['Raheem Sterling' 4.2]
# Substituted: ['John Stones' 3.2] for  ['Vitalii Mykolenko' 3.8]
# Substituted: ['Ederson Santana de Moraes' 3.3] for  ['Manuel Akanji' 3.6]
# Substituted: ['Bruno Guimarães Rodriguez Moura' 3.4] for  ['Abdoulaye Doucouré' 4.1]
# Substituted: ['Leandro Trossard' 3.7] for  ['Kevin De Bruyne' 4.1]
# Final Selection: 0 GK, 4 DEF, 2 FWD, 5 MID
# Current budget spent: 751.0, remaining budget: 89.0
# {'Arsenal': 1, 'Aston Villa': 0, 'Bournemouth': 1, 'Brentford': 0, 'Brighton': 0, 'Burnley': 0, 'Chelsea': 1, 'Crystal Palace': 0, 'Everton': 2, 'Fulham': 1, 'Liverpool': 2, 'Luton': 0, 'Man City': 3, 'Man Utd': 0, 'Newcastle': 0, "Nott'm Forest": 0, 'Sheffield Utd': 0, 'Spurs': 0, 'West Ham': 0, 'Wolves': 0}
#
#     minutes total_points  ppg   cost first_name           second_name  \
# 279    1846           63  3.6   45.0    Rodrigo        Muniz Carvalho
# 341    1635           80  3.6   49.0     Manuel                Akanji
# 342    2128          128  3.6   51.0     Nathan                   Aké
# 260    1570           53  3.8   46.0    Vitalii             Mykolenko
# 303    1721           64  3.8   75.0       Luis                  Díaz
# 249    2236           67  4.1   55.0  Abdoulaye              Doucouré
# 349    1927           61  4.1  106.0      Kevin             De Bruyne
# 5      1683          103  4.1   53.0    Gabriel  dos Santos Magalhães
# 216    1982           66  4.2   69.0     Raheem              Sterling
# 85     1710           73  5.0   72.0    Dominic               Solanke
# 308    1673           83  8.0  130.0    Mohamed                 Salah
#
#             team position news                   news_added expected_points  \
# 279       Fulham      FWD       2023-11-04T15:30:08.544057Z             8.5
# 341     Man City      DEF       2024-01-07T21:30:10.406147Z             4.5
# 342     Man City      DEF       2023-11-13T01:00:09.634159Z             4.7
# 260      Everton      DEF       2024-02-22T15:30:08.434315Z             1.5
# 303    Liverpool      MID       2023-12-23T22:00:09.137690Z             5.5
# 249      Everton      MID       2024-01-25T18:00:09.222232Z             1.8
# 349     Man City      MID       2023-08-12T08:00:06.610027Z             2.1
# 5        Arsenal      DEF       2024-01-20T15:30:09.437664Z             7.5
# 216      Chelsea      MID       2023-12-24T15:30:09.085575Z             3.3
# 85   Bournemouth      FWD       2024-02-28T00:30:09.999722Z            11.0
# 308    Liverpool      MID       2024-02-26T00:30:09.476744Z             2.3
#
#                              name       ppm   ppmcost
# 279        Rodrigo Muniz Carvalho  0.034128  0.758397
# 341                 Manuel Akanji   0.04893  0.998565
# 342                    Nathan Aké   0.06015  1.179419
# 260             Vitalii Mykolenko  0.033758  0.733869
# 303                     Luis Díaz  0.037188  0.495836
# 249            Abdoulaye Doucouré  0.029964  0.544804
# 349               Kevin De Bruyne  0.031655  0.298636
# 5    Gabriel dos Santos Magalhães    0.0612  1.154721
# 216               Raheem Sterling    0.0333  0.482604
# 85                Dominic Solanke   0.04269  0.592917
# 308                 Mohamed Salah  0.049611  0.381627

# %%
xp = eval.copy(deep=True)
minutes_threshold = 1450
xp = xp[xp['minutes'] > minutes_threshold]
xp = xp.sort_values(by='expected_points', ascending=False)
xp = xp[~xp.index.isin(selected_11.index)]
print(f"{len(xp)} players have played more than {minutes_threshold} minutes and selected for expected points algo")


def substitute_for_points():
    global xp, selected_11, team_count, gk_count, def_count, fwd_count, mid_count
    selected_11 = selected_11.sort_values(by=['expected_points', 'ppg', 'ppm', 'ppmcost'], ascending=True)
    # print(selected_11)

    # Substitute the lowest xp player
    for i in selected_11.index:
        if selected_11.loc[i, 'position'] == 'GK':
            gk_count -= 1
        elif selected_11.loc[i, 'position'] == 'DEF':
            def_count -= 1
        elif selected_11.loc[i, 'position'] == 'MID':
            mid_count -= 1
        elif selected_11.loc[i, 'position'] == 'FWD':
            fwd_count -= 1
        team_count[selected_11.loc[i, 'team']] -= 1

        # Find the highest possible xp player
        for j in xp.index:
            sub = False
            if selected_11.loc[i, 'expected_points'] > xp.loc[j, 'expected_points']:
                pass
            elif team_count[xp.loc[j, 'team']] > 2:
                pass
            elif xp.loc[j, 'cost'] + selected_11['cost'].sum() > BUDGET+20:
                pass
            elif xp.loc[j, 'position'] == 'GK' and gk_count > 0:
                pass
            elif xp.loc[j, 'position'] == 'DEF' and def_count > 4:
                pass
            elif xp.loc[j, 'position'] == 'MID' and mid_count > 4:
                pass
            elif xp.loc[j, 'position'] == 'FWD' and fwd_count > 2:
                pass
            else:
                # remove the player from selected_11
                sub = True
                print(f"Substituted: {selected_11.loc[i,['name','expected_points']].values} for  {xp.loc[j, ['name','expected_points']].values}")
                selected_11 = selected_11[~selected_11.index.isin([i])]
                selected_11 = pd.concat([selected_11, xp.loc[j, :].to_frame().T])
                selected_11 = selected_11.sort_values(by=['expected_points', 'ppm', 'ppmcost'], ascending=True)
                team_count[xp.loc[j, 'team']] += 1
                if xp.loc[j, 'position'] == 'GK':
                    gk_count += 1
                elif xp.loc[j, 'position'] == 'DEF':
                    def_count += 1
                elif xp.loc[j, 'position'] == 'MID':
                    mid_count += 1
                elif xp.loc[j, 'position'] == 'FWD':
                    fwd_count += 1
                xp = xp[~xp.index.isin([j])]
                break
        if sub == False:
            if selected_11.loc[i, 'position'] == 'GK':
                gk_count += 1
            elif selected_11.loc[i, 'position'] == 'DEF':
                def_count += 1
            elif selected_11.loc[i, 'position'] == 'MID':
                mid_count += 1
            elif selected_11.loc[i, 'position'] == 'FWD':
                fwd_count += 1
            team_count[selected_11.loc[i, 'team']] += 1
        if selected_11['cost'].sum() > BUDGET:
            print("budget reached")
            break
     
    return selected_11

selected_11 = substitute_for_points()
print(f"Final Selection: {gk_count} GK, {def_count} DEF, {fwd_count} FWD, {mid_count} MID")
print(f"Current budget spent: {selected_11['cost'].sum()}, remaining budget: {BUDGET - selected_11['cost'].sum()}")
print(team_count)
print("")
print(selected_11)
# Out:
# 54 players have played more than 1450 minutes and selected for expected points algo
# Substituted: ['Vitalii Mykolenko' '1.5'] for  ['Milos Kerkez' '5.4']
# Substituted: ['Abdoulaye Doucouré' '1.8'] for  ['Leandro Trossard' '6.2']
# Substituted: ['Dominic Solanke' '11.0'] for  ['Adam Smith' '5.0']
# Substituted: ['Kevin De Bruyne' '2.1'] for  ['Ederson Santana de Moraes' '6.3']
# Substituted: ['Mohamed Salah' '2.3'] for  ['Bruno Guimarães Rodriguez Moura' '6.2']
# Substituted: ['Raheem Sterling' '3.3'] for  ['Ryan Christie' '4.0']
# Substituted: ['Manuel Akanji' '4.5'] for  ['John Stones' '4.5']
# Final Selection: 1 GK, 5 DEF, 1 FWD, 4 MID
# Current budget spent: 593.0, remaining budget: 247.0
# {'Arsenal': 2, 'Aston Villa': 0, 'Bournemouth': 3, 'Brentford': 0, 'Brighton': 0, 'Burnley': 0, 'Chelsea': 0, 'Crystal Palace': 0, 'Everton': 0, 'Fulham': 1, 'Liverpool': 1, 'Luton': 0, 'Man City': 3, 'Man Utd': 0, 'Newcastle': 1, "Nott'm Forest": 0, 'Sheffield Utd': 0, 'Spurs': 0, 'West Ham': 0, 'Wolves': 0}
#
#     minutes total_points  ppg  cost first_name                second_name  \
# 65     1711           51  2.2  50.0       Ryan                   Christie
# 368    2170           82  3.2  53.0       John                     Stones
# 342    2128          128  3.6  51.0     Nathan                        Aké
# 84     2315          130  2.6  44.0       Adam                      Smith
# 595    2430           69  2.1  44.0      Milos                     Kerkez
# 303    1721           64  3.8  75.0       Luis                       Díaz
# 26     1680           20  3.7  65.0    Leandro                   Trossard
# 406    1757           73  3.4  58.0      Bruno  Guimarães Rodriguez Moura
# 352    2220          158  3.3  55.0    Ederson          Santana de Moraes
# 5      1683          103  4.1  53.0    Gabriel       dos Santos Magalhães
# 279    1846           63  3.6  45.0    Rodrigo             Muniz Carvalho
#
#             team position news                   news_added expected_points  \
# 65   Bournemouth      MID       2024-02-05T14:00:08.189778Z             4.0
# 368     Man City      DEF       2023-12-28T09:30:09.480620Z             4.5
# 342     Man City      DEF       2023-11-13T01:00:09.634159Z             4.7
# 84   Bournemouth      DEF       2024-01-22T01:00:09.769539Z             5.0
# 595  Bournemouth      DEF       2023-12-21T15:00:10.669352Z             5.4
# 303    Liverpool      MID       2023-12-23T22:00:09.137690Z             5.5
# 26       Arsenal      MID       2023-10-09T08:30:07.911344Z             6.2
# 406    Newcastle      MID       2023-11-04T21:00:09.029195Z             6.2
# 352     Man City       GK       2024-01-13T22:30:10.940316Z             6.3
# 5        Arsenal      DEF       2024-01-20T15:30:09.437664Z             7.5
# 279       Fulham      FWD       2023-11-04T15:30:08.544057Z             8.5
#
#                                 name       ppm   ppmcost
# 65                     Ryan Christie  0.029807  0.596143
# 368                      John Stones  0.037788  0.712981
# 342                       Nathan Aké   0.06015  1.179419
# 84                        Adam Smith  0.056156  1.276262
# 595                     Milos Kerkez  0.028395  0.645342
# 303                        Luis Díaz  0.037188  0.495836
# 26                  Leandro Trossard  0.011905   0.18315
# 406  Bruno Guimarães Rodriguez Moura  0.041548  0.716346
# 352        Ederson Santana de Moraes  0.071171  1.294021
# 5       Gabriel dos Santos Magalhães    0.0612  1.154721
# 279           Rodrigo Muniz Carvalho  0.034128  0.758397

# %% [markdown]
# Total Model Team Points: 34
#
# - Rodrigo: 2
# - Akanji: 2
# - Aké: 2
# - Mykolenko: 1
# - Luis Díaz: 2
# - Abdoulaye: 1
# - De Bruyne: 6
# - Gabriel: 1
# - Sterling: 1
# - Solanke: 16 (C)
# - Salah: 0

# %%
general_data['elements']
# Out:
# [{'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 232223,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -1,
#   'cost_change_start_fall': 1,
#   'dreamteam_count': 0,
#   'element_type': 4,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Folarin',
#   'form': '0.0',
#   'id': 1,
#   'in_dreamteam': False,
#   'news': 'Transferred to Monaco',
#   'news_added': '2023-08-31T08:55:15.272751Z',
#   'now_cost': 44,
#   'photo': '232223.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Balogun',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 10024,
#   'transfers_in_event': 0,
#   'transfers_out': 63211,
#   'transfers_out_event': 81,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Balogun',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 676,
#   'influence_rank_type': 68,
#   'creativity_rank': 668,
#   'creativity_rank_type': 69,
#   'threat_rank': 641,
#   'threat_rank_type': 66,
#   'ict_index_rank': 679,
#   'ict_index_rank_type': 70,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 551,
#   'now_cost_rank_type': 100,
#   'form_rank': 586,
#   'form_rank_type': 51,
#   'points_per_game_rank': 688,
#   'points_per_game_rank_type': 74,
#   'selected_rank': 335,
#   'selected_rank_type': 53,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 58822,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -2,
#   'cost_change_start_fall': 2,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '1.8',
#   'ep_this': '2.3',
#   'event_points': 1,
#   'first_name': 'Cédric',
#   'form': '0.8',
#   'id': 2,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 38,
#   'photo': '58822.jpg',
#   'points_per_game': '1.0',
#   'second_name': 'Alves Soares',
#   'selected_by_percent': '0.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 3,
#   'transfers_in': 42492,
#   'transfers_in_event': 2579,
#   'transfers_out': 48946,
#   'transfers_out_event': 1251,
#   'value_form': '0.2',
#   'value_season': '0.8',
#   'web_name': 'Cédric',
#   'minutes': 59,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 15,
#   'influence': '2.0',
#   'creativity': '4.3',
#   'threat': '0.0',
#   'ict_index': '0.6',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.02',
#   'expected_goal_involvements': '0.02',
#   'expected_goals_conceded': '0.39',
#   'influence_rank': 514,
#   'influence_rank_type': 185,
#   'creativity_rank': 450,
#   'creativity_rank_type': 164,
#   'threat_rank': 467,
#   'threat_rank_type': 169,
#   'ict_index_rank': 507,
#   'ict_index_rank_type': 180,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.03,
#   'expected_goal_involvements_per_90': 0.03,
#   'expected_goals_conceded_per_90': 0.59,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 826,
#   'now_cost_rank_type': 264,
#   'form_rank': 258,
#   'form_rank_type': 84,
#   'points_per_game_rank': 433,
#   'points_per_game_rank_type': 151,
#   'selected_rank': 258,
#   'selected_rank_type': 101,
#   'starts_per_90': 0.0,
#   'clean_sheets_per_90': 0.0},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 153256,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -1,
#   'cost_change_start_fall': 1,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '1.5',
#   'ep_this': '2.0',
#   'event_points': 0,
#   'first_name': 'Mohamed',
#   'form': '0.5',
#   'id': 3,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2023-12-30T22:30:09.113694Z',
#   'now_cost': 44,
#   'photo': '153256.jpg',
#   'points_per_game': '2.0',
#   'second_name': 'Elneny',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 6,
#   'transfers_in': 13343,
#   'transfers_in_event': 40,
#   'transfers_out': 19977,
#   'transfers_out_event': 114,
#   'value_form': '0.1',
#   'value_season': '1.4',
#   'web_name': 'M.Elneny',
#   'minutes': 25,
#   'goals_scored': 0,
#   'assists': 1,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 16,
#   'influence': '4.0',
#   'creativity': '2.1',
#   'threat': '10.0',
#   'ict_index': '1.6',
#   'starts': 0,
#   'expected_goals': '0.08',
#   'expected_assists': '0.01',
#   'expected_goal_involvements': '0.09',
#   'expected_goals_conceded': '0.13',
#   'influence_rank': 498,
#   'influence_rank_type': 224,
#   'creativity_rank': 462,
#   'creativity_rank_type': 227,
#   'threat_rank': 426,
#   'threat_rank_type': 212,
#   'ict_index_rank': 495,
#   'ict_index_rank_type': 225,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.29,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.04,
#   'expected_goal_involvements_per_90': 0.33,
#   'expected_goals_conceded_per_90': 0.47,
#   'goals_conceded_per_90': 0.0,
#   'now_cost_rank': 525,
#   'now_cost_rank_type': 310,
#   'form_rank': 306,
#   'form_rank_type': 144,
#   'points_per_game_rank': 301,
#   'points_per_game_rank_type': 127,
#   'selected_rank': 468,
#   'selected_rank_type': 156,
#   'starts_per_90': 0.0,
#   'clean_sheets_per_90': 0.0},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 438098,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -1,
#   'cost_change_start_fall': 1,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '1.2',
#   'ep_this': '1.7',
#   'event_points': 1,
#   'first_name': 'Fábio',
#   'form': '0.2',
#   'id': 4,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2023-12-07T12:00:08.489004Z',
#   'now_cost': 54,
#   'photo': '438098.jpg',
#   'points_per_game': '2.4',
#   'second_name': 'Ferreira Vieira',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 22,
#   'transfers_in': 11587,
#   'transfers_in_event': 35,
#   'transfers_out': 18918,
#   'transfers_out_event': 33,
#   'value_form': '0.0',
#   'value_season': '4.1',
#   'web_name': 'Fábio Vieira',
#   'minutes': 281,
#   'goals_scored': 1,
#   'assists': 3,
#   'clean_sheets': 1,
#   'goals_conceded': 2,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 1,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 65,
#   'influence': '82.2',
#   'creativity': '77.7',
#   'threat': '79.0',
#   'ict_index': '23.8',
#   'starts': 2,
#   'expected_goals': '1.20',
#   'expected_assists': '0.58',
#   'expected_goal_involvements': '1.78',
#   'expected_goals_conceded': '1.68',
#   'influence_rank': 370,
#   'influence_rank_type': 156,
#   'creativity_rank': 294,
#   'creativity_rank_type': 163,
#   'threat_rank': 258,
#   'threat_rank_type': 135,
#   'ict_index_rank': 351,
#   'ict_index_rank_type': 158,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': 4,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.38,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.19,
#   'expected_goal_involvements_per_90': 0.57,
#   'expected_goals_conceded_per_90': 0.54,
#   'goals_conceded_per_90': 0.64,
#   'now_cost_rank': 125,
#   'now_cost_rank_type': 77,
#   'form_rank': 382,
#   'form_rank_type': 183,
#   'points_per_game_rank': 254,
#   'points_per_game_rank_type': 109,
#   'selected_rank': 449,
#   'selected_rank_type': 148,
#   'starts_per_90': 0.64,
#   'clean_sheets_per_90': 0.32},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 226597,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 3,
#   'cost_change_start_fall': -3,
#   'dreamteam_count': 3,
#   'element_type': 2,
#   'ep_next': '7.5',
#   'ep_this': '8.0',
#   'event_points': 6,
#   'first_name': 'Gabriel',
#   'form': '6.5',
#   'id': 5,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2024-01-20T15:30:09.437664Z',
#   'now_cost': 53,
#   'photo': '226597.jpg',
#   'points_per_game': '4.1',
#   'second_name': 'dos Santos Magalhães',
#   'selected_by_percent': '27.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 102,
#   'transfers_in': 2783446,
#   'transfers_in_event': 86110,
#   'transfers_out': 2841590,
#   'transfers_out_event': 23490,
#   'value_form': '1.2',
#   'value_season': '19.2',
#   'web_name': 'Gabriel',
#   'minutes': 2084,
#   'goals_scored': 3,
#   'assists': 1,
#   'clean_sheets': 9,
#   'goals_conceded': 20,
#   'own_goals': 1,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 6,
#   'bps': 463,
#   'influence': '523.0',
#   'creativity': '103.3',
#   'threat': '289.0',
#   'ict_index': '91.7',
#   'starts': 23,
#   'expected_goals': '3.11',
#   'expected_assists': '0.51',
#   'expected_goal_involvements': '3.62',
#   'expected_goals_conceded': '16.74',
#   'influence_rank': 52,
#   'influence_rank_type': 16,
#   'creativity_rank': 251,
#   'creativity_rank_type': 72,
#   'threat_rank': 88,
#   'threat_rank_type': 4,
#   'ict_index_rank': 107,
#   'ict_index_rank_type': 20,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.13,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.02,
#   'expected_goal_involvements_per_90': 0.15,
#   'expected_goals_conceded_per_90': 0.72,
#   'goals_conceded_per_90': 0.86,
#   'now_cost_rank': 146,
#   'now_cost_rank_type': 15,
#   'form_rank': 13,
#   'form_rank_type': 3,
#   'points_per_game_rank': 43,
#   'points_per_game_rank_type': 5,
#   'selected_rank': 10,
#   'selected_rank_type': 3,
#   'starts_per_90': 0.99,
#   'clean_sheets_per_90': 0.39},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 219847,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -4,
#   'cost_change_start_fall': 4,
#   'dreamteam_count': 2,
#   'element_type': 3,
#   'ep_next': '11.8',
#   'ep_this': '12.3',
#   'event_points': 14,
#   'first_name': 'Kai',
#   'form': '10.8',
#   'id': 6,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2023-12-23T20:00:08.458889Z',
#   'now_cost': 71,
#   'photo': '219847.jpg',
#   'points_per_game': '4.0',
#   'second_name': 'Havertz',
#   'selected_by_percent': '2.8',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 103,
#   'transfers_in': 238966,
#   'transfers_in_event': 66020,
#   'transfers_out': 424548,
#   'transfers_out_event': 5460,
#   'value_form': '1.5',
#   'value_season': '14.5',
#   'web_name': 'Havertz',
#   'minutes': 1683,
#   'goals_scored': 7,
#   'assists': 5,
#   'clean_sheets': 9,
#   'goals_conceded': 16,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 6,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 7,
#   'bps': 288,
#   'influence': '407.8',
#   'creativity': '373.9',
#   'threat': '478.0',
#   'ict_index': '125.9',
#   'starts': 19,
#   'expected_goals': '7.38',
#   'expected_assists': '1.72',
#   'expected_goal_involvements': '9.10',
#   'expected_goals_conceded': '11.87',
#   'influence_rank': 104,
#   'influence_rank_type': 42,
#   'creativity_rank': 66,
#   'creativity_rank_type': 53,
#   'threat_rank': 38,
#   'threat_rank_type': 22,
#   'ict_index_rank': 53,
#   'ict_index_rank_type': 41,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': 3,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.39,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.09,
#   'expected_goal_involvements_per_90': 0.48,
#   'expected_goals_conceded_per_90': 0.63,
#   'goals_conceded_per_90': 0.86,
#   'now_cost_rank': 29,
#   'now_cost_rank_type': 16,
#   'form_rank': 2,
#   'form_rank_type': 2,
#   'points_per_game_rank': 54,
#   'points_per_game_rank_type': 31,
#   'selected_rank': 115,
#   'selected_rank_type': 36,
#   'starts_per_90': 1.02,
#   'clean_sheets_per_90': 0.48},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 205651,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -2,
#   'cost_change_start_fall': 2,
#   'dreamteam_count': 1,
#   'element_type': 4,
#   'ep_next': '1.2',
#   'ep_this': '1.7',
#   'event_points': 1,
#   'first_name': 'Gabriel',
#   'form': '0.2',
#   'id': 8,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2024-02-05T08:30:09.036230Z',
#   'now_cost': 78,
#   'photo': '205651.jpg',
#   'points_per_game': '3.6',
#   'second_name': 'Fernando de Jesus',
#   'selected_by_percent': '2.6',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 64,
#   'transfers_in': 1058812,
#   'transfers_in_event': 4525,
#   'transfers_out': 1140318,
#   'transfers_out_event': 10355,
#   'value_form': '0.0',
#   'value_season': '8.2',
#   'web_name': 'G.Jesus',
#   'minutes': 1117,
#   'goals_scored': 4,
#   'assists': 4,
#   'clean_sheets': 7,
#   'goals_conceded': 11,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 5,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 10,
#   'bps': 212,
#   'influence': '300.0',
#   'creativity': '317.5',
#   'threat': '626.0',
#   'ict_index': '124.4',
#   'starts': 13,
#   'expected_goals': '5.35',
#   'expected_assists': '2.13',
#   'expected_goal_involvements': '7.48',
#   'expected_goals_conceded': '9.58',
#   'influence_rank': 187,
#   'influence_rank_type': 20,
#   'creativity_rank': 81,
#   'creativity_rank_type': 7,
#   'threat_rank': 21,
#   'threat_rank_type': 9,
#   'ict_index_rank': 55,
#   'ict_index_rank_type': 10,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.43,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.17,
#   'expected_goal_involvements_per_90': 0.6,
#   'expected_goals_conceded_per_90': 0.77,
#   'goals_conceded_per_90': 0.89,
#   'now_cost_rank': 18,
#   'now_cost_rank_type': 6,
#   'form_rank': 389,
#   'form_rank_type': 47,
#   'points_per_game_rank': 88,
#   'points_per_game_rank_type': 19,
#   'selected_rank': 124,
#   'selected_rank_type': 21,
#   'starts_per_90': 1.05,
#   'clean_sheets_per_90': 0.56},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 85955,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -2,
#   'cost_change_start_fall': 2,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '2.5',
#   'ep_this': '3.0',
#   'event_points': 3,
#   'first_name': 'Jorge Luiz',
#   'form': '1.5',
#   'id': 9,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2023-12-18T00:00:09.353001Z',
#   'now_cost': 53,
#   'photo': '85955.jpg',
#   'points_per_game': '1.6',
#   'second_name': 'Frello Filho',
#   'selected_by_percent': '0.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 28,
#   'transfers_in': 10691,
#   'transfers_in_event': 166,
#   'transfers_out': 20454,
#   'transfers_out_event': 214,
#   'value_form': '0.3',
#   'value_season': '5.3',
#   'web_name': 'Jorginho',
#   'minutes': 654,
#   'goals_scored': 0,
#   'assists': 1,
#   'clean_sheets': 2,
#   'goals_conceded': 8,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 125,
#   'influence': '114.4',
#   'creativity': '138.9',
#   'threat': '10.0',
#   'ict_index': '26.4',
#   'starts': 7,
#   'expected_goals': '0.10',
#   'expected_assists': '0.90',
#   'expected_goal_involvements': '1.00',
#   'expected_goals_conceded': '5.73',
#   'influence_rank': 333,
#   'influence_rank_type': 141,
#   'creativity_rank': 198,
#   'creativity_rank_type': 126,
#   'threat_rank': 427,
#   'threat_rank_type': 213,
#   'ict_index_rank': 335,
#   'ict_index_rank_type': 150,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.01,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.12,
#   'expected_goal_involvements_per_90': 0.13,
#   'expected_goals_conceded_per_90': 0.79,
#   'goals_conceded_per_90': 1.1,
#   'now_cost_rank': 130,
#   'now_cost_rank_type': 80,
#   'form_rank': 206,
#   'form_rank_type': 98,
#   'points_per_game_rank': 371,
#   'points_per_game_rank_type': 165,
#   'selected_rank': 337,
#   'selected_rank_type': 105,
#   'starts_per_90': 0.96,
#   'clean_sheets_per_90': 0.28},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 440854,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -2,
#   'cost_change_start_fall': 2,
#   'dreamteam_count': 1,
#   'element_type': 2,
#   'ep_next': '9.2',
#   'ep_this': '9.7',
#   'event_points': 10,
#   'first_name': 'Jakub',
#   'form': '8.2',
#   'id': 10,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 43,
#   'photo': '440854.jpg',
#   'points_per_game': '3.4',
#   'second_name': 'Kiwior',
#   'selected_by_percent': '1.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 51,
#   'transfers_in': 151795,
#   'transfers_in_event': 45174,
#   'transfers_out': 21512,
#   'transfers_out_event': 2935,
#   'value_form': '1.9',
#   'value_season': '11.9',
#   'web_name': 'Kiwior',
#   'minutes': 707,
#   'goals_scored': 1,
#   'assists': 3,
#   'clean_sheets': 4,
#   'goals_conceded': 7,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 1,
#   'bps': 200,
#   'influence': '202.2',
#   'creativity': '75.8',
#   'threat': '82.0',
#   'ict_index': '36.1',
#   'starts': 8,
#   'expected_goals': '0.74',
#   'expected_assists': '0.50',
#   'expected_goal_involvements': '1.24',
#   'expected_goals_conceded': '3.29',
#   'influence_rank': 256,
#   'influence_rank_type': 96,
#   'creativity_rank': 299,
#   'creativity_rank_type': 95,
#   'threat_rank': 248,
#   'threat_rank_type': 73,
#   'ict_index_rank': 286,
#   'ict_index_rank_type': 96,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.09,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.06,
#   'expected_goal_involvements_per_90': 0.15,
#   'expected_goals_conceded_per_90': 0.42,
#   'goals_conceded_per_90': 0.89,
#   'now_cost_rank': 637,
#   'now_cost_rank_type': 148,
#   'form_rank': 7,
#   'form_rank_type': 1,
#   'points_per_game_rank': 102,
#   'points_per_game_rank_type': 17,
#   'selected_rank': 173,
#   'selected_rank_type': 73,
#   'starts_per_90': 1.02,
#   'clean_sheets_per_90': 0.51},
#  {'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 479683,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Marcus',
#   'form': '0.0',
#   'id': 11,
#   'in_dreamteam': False,
#   'news': 'Season long loan to FC Nantes',
#   'news_added': '2023-08-14T03:57:12.475590Z',
#   'now_cost': 45,
#   'photo': '479683.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Oliveira Alencar',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 819,
#   'transfers_in_event': 0,
#   'transfers_out': 11876,
#   'transfers_out_event': 11,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Marquinhos',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 729,
#   'influence_rank_type': 289,
#   'creativity_rank': 723,
#   'creativity_rank_type': 288,
#   'threat_rank': 711,
#   'threat_rank_type': 283,
#   'ict_index_rank': 732,
#   'ict_index_rank_type': 290,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 435,
#   'now_cost_rank_type': 252,
#   'form_rank': 656,
#   'form_rank_type': 244,
#   'points_per_game_rank': 732,
#   'points_per_game_rank_type': 291,
#   'selected_rank': 547,
#   'selected_rank_type': 193,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': 75,
#   'chance_of_playing_this_round': 100,
#   'code': 444145,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -3,
#   'cost_change_start_fall': 3,
#   'dreamteam_count': 2,
#   'element_type': 3,
#   'ep_next': '5.1',
#   'ep_this': '7.3',
#   'event_points': 11,
#   'first_name': 'Gabriel',
#   'form': '5.8',
#   'id': 12,
#   'in_dreamteam': False,
#   'news': 'Gashed Leg - 75% chance of playing',
#   'news_added': '2024-03-05T09:00:08.920090Z',
#   'now_cost': 77,
#   'photo': '444145.jpg',
#   'points_per_game': '4.3',
#   'second_name': 'Martinelli Silva',
#   'selected_by_percent': '5.8',
#   'special': False,
#   'squad_number': None,
#   'status': 'd',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 107,
#   'transfers_in': 1235489,
#   'transfers_in_event': 10618,
#   'transfers_out': 2071109,
#   'transfers_out_event': 42114,
#   'value_form': '0.8',
#   'value_season': '13.9',
#   'web_name': 'Martinelli',
#   'minutes': 1748,
#   'goals_scored': 6,
#   'assists': 5,
#   'clean_sheets': 10,
#   'goals_conceded': 18,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 1,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 6,
#   'bps': 356,
#   'influence': '433.8',
#   'creativity': '602.9',
#   'threat': '657.0',
#   'ict_index': '168.9',
#   'starts': 23,
#   'expected_goals': '5.17',
#   'expected_assists': '4.48',
#   'expected_goal_involvements': '9.64',
#   'expected_goals_conceded': '11.73',
#   'influence_rank': 95,
#   'influence_rank_type': 35,
#   'creativity_rank': 23,
#   'creativity_rank_type': 18,
#   'threat_rank': 17,
#   'threat_rank_type': 10,
#   'ict_index_rank': 20,
#   'ict_index_rank_type': 14,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.27,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.23,
#   'expected_goal_involvements_per_90': 0.5,
#   'expected_goals_conceded_per_90': 0.6,
#   'goals_conceded_per_90': 0.93,
#   'now_cost_rank': 19,
#   'now_cost_rank_type': 12,
#   'form_rank': 27,
#   'form_rank_type': 18,
#   'points_per_game_rank': 36,
#   'points_per_game_rank_type': 26,
#   'selected_rank': 66,
#   'selected_rank_type': 21,
#   'starts_per_90': 1.18,
#   'clean_sheets_per_90': 0.51},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 205533,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -4,
#   'cost_change_start_fall': 4,
#   'dreamteam_count': 1,
#   'element_type': 4,
#   'ep_next': '1.8',
#   'ep_this': '2.3',
#   'event_points': 0,
#   'first_name': 'Eddie',
#   'form': '0.8',
#   'id': 13,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2023-11-09T08:30:08.250179Z',
#   'now_cost': 51,
#   'photo': '205533.jpg',
#   'points_per_game': '2.8',
#   'second_name': 'Nketiah',
#   'selected_by_percent': '3.4',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 68,
#   'transfers_in': 1579121,
#   'transfers_in_event': 1368,
#   'transfers_out': 1671360,
#   'transfers_out_event': 11056,
#   'value_form': '0.2',
#   'value_season': '13.3',
#   'web_name': 'Nketiah',
#   'minutes': 1037,
#   'goals_scored': 5,
#   'assists': 4,
#   'clean_sheets': 6,
#   'goals_conceded': 10,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 5,
#   'bps': 205,
#   'influence': '232.8',
#   'creativity': '135.4',
#   'threat': '392.0',
#   'ict_index': '74.6',
#   'starts': 10,
#   'expected_goals': '4.52',
#   'expected_assists': '0.52',
#   'expected_goal_involvements': '5.04',
#   'expected_goals_conceded': '9.89',
#   'influence_rank': 232,
#   'influence_rank_type': 29,
#   'creativity_rank': 202,
#   'creativity_rank_type': 28,
#   'threat_rank': 57,
#   'threat_rank_type': 23,
#   'ict_index_rank': 145,
#   'ict_index_rank_type': 27,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.39,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.05,
#   'expected_goal_involvements_per_90': 0.44,
#   'expected_goals_conceded_per_90': 0.86,
#   'goals_conceded_per_90': 0.87,
#   'now_cost_rank': 166,
#   'now_cost_rank_type': 41,
#   'form_rank': 289,
#   'form_rank_type': 33,
#   'points_per_game_rank': 173,
#   'points_per_game_rank_type': 29,
#   'selected_rank': 98,
#   'selected_rank_type': 16,
#   'starts_per_90': 0.87,
#   'clean_sheets_per_90': 0.52},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 184029,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 2,
#   'element_type': 3,
#   'ep_next': '10.0',
#   'ep_this': '10.5',
#   'event_points': 10,
#   'first_name': 'Martin',
#   'form': '9.0',
#   'id': 14,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2023-11-04T21:00:08.152623Z',
#   'now_cost': 85,
#   'photo': '184029.jpg',
#   'points_per_game': '5.2',
#   'second_name': 'Ødegaard',
#   'selected_by_percent': '17.5',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 126,
#   'transfers_in': 2357139,
#   'transfers_in_event': 80312,
#   'transfers_out': 3027952,
#   'transfers_out_event': 25065,
#   'value_form': '1.1',
#   'value_season': '14.8',
#   'web_name': 'Ødegaard',
#   'minutes': 2124,
#   'goals_scored': 6,
#   'assists': 7,
#   'clean_sheets': 11,
#   'goals_conceded': 19,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 2,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 18,
#   'bps': 494,
#   'influence': '626.2',
#   'creativity': '1030.1',
#   'threat': '517.0',
#   'ict_index': '217.3',
#   'starts': 24,
#   'expected_goals': '5.42',
#   'expected_assists': '6.70',
#   'expected_goal_involvements': '12.12',
#   'expected_goals_conceded': '16.68',
#   'influence_rank': 33,
#   'influence_rank_type': 13,
#   'creativity_rank': 3,
#   'creativity_rank_type': 3,
#   'threat_rank': 34,
#   'threat_rank_type': 19,
#   'ict_index_rank': 8,
#   'ict_index_rank_type': 6,
#   'corners_and_indirect_freekicks_order': 3,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': 1,
#   'direct_freekicks_text': '',
#   'penalties_order': 2,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.23,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.28,
#   'expected_goal_involvements_per_90': 0.51,
#   'expected_goals_conceded_per_90': 0.71,
#   'goals_conceded_per_90': 0.81,
#   'now_cost_rank': 9,
#   'now_cost_rank_type': 5,
#   'form_rank': 4,
#   'form_rank_type': 3,
#   'points_per_game_rank': 16,
#   'points_per_game_rank_type': 13,
#   'selected_rank': 18,
#   'selected_rank_type': 8,
#   'starts_per_90': 1.02,
#   'clean_sheets_per_90': 0.47},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 75,
#   'code': 167199,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -2,
#   'cost_change_start_fall': 2,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '1.2',
#   'ep_this': '1.3',
#   'event_points': 1,
#   'first_name': 'Thomas',
#   'form': '0.2',
#   'id': 15,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2023-10-25T12:00:07.465521Z',
#   'now_cost': 48,
#   'photo': '167199.jpg',
#   'points_per_game': '1.6',
#   'second_name': 'Partey',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 8,
#   'transfers_in': 8716,
#   'transfers_in_event': 42,
#   'transfers_out': 37747,
#   'transfers_out_event': 40,
#   'value_form': '0.0',
#   'value_season': '1.7',
#   'web_name': 'Thomas',
#   'minutes': 275,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 1,
#   'goals_conceded': 2,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 65,
#   'influence': '57.6',
#   'creativity': '61.9',
#   'threat': '17.0',
#   'ict_index': '13.7',
#   'starts': 3,
#   'expected_goals': '0.07',
#   'expected_assists': '0.25',
#   'expected_goal_involvements': '0.32',
#   'expected_goals_conceded': '2.64',
#   'influence_rank': 403,
#   'influence_rank_type': 174,
#   'creativity_rank': 320,
#   'creativity_rank_type': 170,
#   'threat_rank': 404,
#   'threat_rank_type': 201,
#   'ict_index_rank': 405,
#   'ict_index_rank_type': 185,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.02,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.08,
#   'expected_goal_involvements_per_90': 0.1,
#   'expected_goals_conceded_per_90': 0.86,
#   'goals_conceded_per_90': 0.65,
#   'now_cost_rank': 284,
#   'now_cost_rank_type': 184,
#   'form_rank': 376,
#   'form_rank_type': 178,
#   'points_per_game_rank': 366,
#   'points_per_game_rank_type': 160,
#   'selected_rank': 370,
#   'selected_rank_type': 119,
#   'starts_per_90': 0.98,
#   'clean_sheets_per_90': 0.33},
#  {'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 195735,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -1,
#   'cost_change_start_fall': 1,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Nicolas',
#   'form': '0.0',
#   'id': 16,
#   'in_dreamteam': False,
#   'news': 'Permanent move to Trabzonspor',
#   'news_added': '2023-09-11T14:13:51.462896Z',
#   'now_cost': 49,
#   'photo': '195735.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Pépé',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 667,
#   'transfers_in_event': 0,
#   'transfers_out': 6464,
#   'transfers_out_event': 7,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Pepe',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 798,
#   'influence_rank_type': 340,
#   'creativity_rank': 794,
#   'creativity_rank_type': 339,
#   'threat_rank': 790,
#   'threat_rank_type': 337,
#   'ict_index_rank': 799,
#   'ict_index_rank_type': 340,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 236,
#   'now_cost_rank_type': 152,
#   'form_rank': 761,
#   'form_rank_type': 318,
#   'points_per_game_rank': 798,
#   'points_per_game_rank_type': 340,
#   'selected_rank': 543,
#   'selected_rank_type': 190,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 225321,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -5,
#   'cost_change_start_fall': 5,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '1.0',
#   'ep_this': '1.5',
#   'event_points': 0,
#   'first_name': 'Aaron',
#   'form': '0.0',
#   'id': 17,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '225321.jpg',
#   'points_per_game': '3.4',
#   'second_name': 'Ramsdale',
#   'selected_by_percent': '5.8',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 17,
#   'transfers_in': 277794,
#   'transfers_in_event': 9335,
#   'transfers_out': 1492392,
#   'transfers_out_event': 5564,
#   'value_form': '0.0',
#   'value_season': '3.8',
#   'web_name': 'Ramsdale',
#   'minutes': 450,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 2,
#   'goals_conceded': 4,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 6,
#   'bonus': 0,
#   'bps': 77,
#   'influence': '55.8',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '5.6',
#   'starts': 5,
#   'expected_goals': '0.00',
#   'expected_assists': '0.01',
#   'expected_goal_involvements': '0.01',
#   'expected_goals_conceded': '4.84',
#   'influence_rank': 405,
#   'influence_rank_type': 30,
#   'creativity_rank': 700,
#   'creativity_rank_type': 86,
#   'threat_rank': 682,
#   'threat_rank_type': 80,
#   'ict_index_rank': 452,
#   'ict_index_rank_type': 30,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.0,
#   'saves_per_90': 1.2,
#   'expected_assists_per_90': 0.0,
#   'expected_goal_involvements_per_90': 0.0,
#   'expected_goals_conceded_per_90': 0.97,
#   'goals_conceded_per_90': 0.8,
#   'now_cost_rank': 389,
#   'now_cost_rank_type': 21,
#   'form_rank': 627,
#   'form_rank_type': 90,
#   'points_per_game_rank': 103,
#   'points_per_game_rank_type': 13,
#   'selected_rank': 67,
#   'selected_rank_type': 13,
#   'starts_per_90': 1.0,
#   'clean_sheets_per_90': 0.4},
#  {'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 115918,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 1,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Rúnar Alex',
#   'form': '0.0',
#   'id': 18,
#   'in_dreamteam': False,
#   'news': 'Contract terminated',
#   'news_added': '2023-08-20T06:33:02.960208Z',
#   'now_cost': 40,
#   'photo': '115918.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Rúnarsson',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 990,
#   'transfers_in_event': 0,
#   'transfers_out': 11475,
#   'transfers_out_event': 48,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Rúnarsson',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 567,
#   'influence_rank_type': 64,
#   'creativity_rank': 554,
#   'creativity_rank_type': 47,
#   'threat_rank': 515,
#   'threat_rank_type': 36,
#   'ict_index_rank': 571,
#   'ict_index_rank_type': 64,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 683,
#   'now_cost_rank_type': 42,
#   'form_rank': 441,
#   'form_rank_type': 57,
#   'points_per_game_rank': 578,
#   'points_per_game_rank_type': 64,
#   'selected_rank': 456,
#   'selected_rank_type': 64,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': 75,
#   'chance_of_playing_this_round': 100,
#   'code': 223340,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 7,
#   'cost_change_start_fall': -7,
#   'dreamteam_count': 4,
#   'element_type': 3,
#   'ep_next': '9.6',
#   'ep_this': '13.3',
#   'event_points': 7,
#   'first_name': 'Bukayo',
#   'form': '11.8',
#   'id': 19,
#   'in_dreamteam': True,
#   'news': 'Illness - 75% chance of playing',
#   'news_added': '2024-03-07T14:30:07.436179Z',
#   'now_cost': 92,
#   'photo': '223340.jpg',
#   'points_per_game': '6.8',
#   'second_name': 'Saka',
#   'selected_by_percent': '65.8',
#   'special': False,
#   'squad_number': None,
#   'status': 'd',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 176,
#   'transfers_in': 5835597,
#   'transfers_in_event': 67257,
#   'transfers_out': 4963060,
#   'transfers_out_event': 137558,
#   'value_form': '1.3',
#   'value_season': '19.1',
#   'web_name': 'Saka',
#   'minutes': 2175,
#   'goals_scored': 13,
#   'assists': 10,
#   'clean_sheets': 10,
#   'goals_conceded': 22,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 23,
#   'bps': 610,
#   'influence': '859.4',
#   'creativity': '975.5',
#   'threat': '983.0',
#   'ict_index': '282.0',
#   'starts': 26,
#   'expected_goals': '11.44',
#   'expected_assists': '8.72',
#   'expected_goal_involvements': '20.16',
#   'expected_goals_conceded': '17.32',
#   'influence_rank': 2,
#   'influence_rank_type': 1,
#   'creativity_rank': 5,
#   'creativity_rank_type': 4,
#   'threat_rank': 4,
#   'threat_rank_type': 1,
#   'ict_index_rank': 1,
#   'ict_index_rank_type': 1,
#   'corners_and_indirect_freekicks_order': 1,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': 1,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.47,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.36,
#   'expected_goal_involvements_per_90': 0.83,
#   'expected_goals_conceded_per_90': 0.72,
#   'goals_conceded_per_90': 0.91,
#   'now_cost_rank': 6,
#   'now_cost_rank_type': 4,
#   'form_rank': 1,
#   'form_rank_type': 1,
#   'points_per_game_rank': 5,
#   'points_per_game_rank_type': 2,
#   'selected_rank': 2,
#   'selected_rank_type': 1,
#   'starts_per_90': 1.08,
#   'clean_sheets_per_90': 0.41},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 462424,
#   'cost_change_event': 1,
#   'cost_change_event_fall': -1,
#   'cost_change_start': 8,
#   'cost_change_start_fall': -8,
#   'dreamteam_count': 1,
#   'element_type': 2,
#   'ep_next': '7.5',
#   'ep_this': '8.0',
#   'event_points': 6,
#   'first_name': 'William',
#   'form': '6.5',
#   'id': 20,
#   'in_dreamteam': True,
#   'news': '',
#   'news_added': '2023-10-09T08:30:07.861646Z',
#   'now_cost': 58,
#   'photo': '462424.jpg',
#   'points_per_game': '4.1',
#   'second_name': 'Saliba',
#   'selected_by_percent': '40.2',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 110,
#   'transfers_in': 4305250,
#   'transfers_in_event': 88465,
#   'transfers_out': 2307919,
#   'transfers_out_event': 32538,
#   'value_form': '1.1',
#   'value_season': '19.0',
#   'web_name': 'Saliba',
#   'minutes': 2430,
#   'goals_scored': 2,
#   'assists': 1,
#   'clean_sheets': 11,
#   'goals_conceded': 23,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 3,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 6,
#   'bps': 537,
#   'influence': '509.8',
#   'creativity': '121.9',
#   'threat': '110.0',
#   'ict_index': '74.3',
#   'starts': 27,
#   'expected_goals': '1.54',
#   'expected_assists': '0.76',
#   'expected_goal_involvements': '2.30',
#   'expected_goals_conceded': '18.84',
#   'influence_rank': 55,
#   'influence_rank_type': 18,
#   'creativity_rank': 221,
#   'creativity_rank_type': 57,
#   'threat_rank': 211,
#   'threat_rank_type': 52,
#   'ict_index_rank': 147,
#   'ict_index_rank_type': 37,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.06,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.03,
#   'expected_goal_involvements_per_90': 0.09,
#   'expected_goals_conceded_per_90': 0.7,
#   'goals_conceded_per_90': 0.85,
#   'now_cost_rank': 78,
#   'now_cost_rank_type': 6,
#   'form_rank': 14,
#   'form_rank_type': 4,
#   'points_per_game_rank': 47,
#   'points_per_game_rank_type': 6,
#   'selected_rank': 4,
#   'selected_rank_type': 1,
#   'starts_per_90': 1.0,
#   'clean_sheets_per_90': 0.41},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 209289,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -2,
#   'cost_change_start_fall': 2,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '1.5',
#   'ep_this': '2.0',
#   'event_points': 0,
#   'first_name': 'Emile',
#   'form': '0.5',
#   'id': 22,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2024-02-12T00:00:07.746307Z',
#   'now_cost': 53,
#   'photo': '209289.jpg',
#   'points_per_game': '1.7',
#   'second_name': 'Smith Rowe',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 17,
#   'transfers_in': 5961,
#   'transfers_in_event': 26,
#   'transfers_out': 17426,
#   'transfers_out_event': 86,
#   'value_form': '0.1',
#   'value_season': '3.2',
#   'web_name': 'Smith Rowe',
#   'minutes': 227,
#   'goals_scored': 0,
#   'assists': 1,
#   'clean_sheets': 2,
#   'goals_conceded': 1,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 47,
#   'influence': '48.6',
#   'creativity': '40.7',
#   'threat': '88.0',
#   'ict_index': '17.4',
#   'starts': 2,
#   'expected_goals': '1.35',
#   'expected_assists': '0.35',
#   'expected_goal_involvements': '1.70',
#   'expected_goals_conceded': '1.27',
#   'influence_rank': 416,
#   'influence_rank_type': 181,
#   'creativity_rank': 360,
#   'creativity_rank_type': 185,
#   'threat_rank': 238,
#   'threat_rank_type': 124,
#   'ict_index_rank': 377,
#   'ict_index_rank_type': 170,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0.54,
#   'saves_per_90': 0.0,
#   'expected_assists_per_90': 0.14,
#   'expected_goal_involvements_per_90': 0.68,
#   'expected_goals_conceded_per_90': 0.5,
#   'goals_conceded_per_90': 0.4,
#   'now_cost_rank': 144,
#   'now_cost_rank_type': 90,
#   'form_rank': 329,
#   'form_rank_type': 160,
#   'points_per_game_rank': 355,
#   'points_per_game_rank_type': 157,
#   'selected_rank': 422,
#   'selected_rank_type': 134,
#   'starts_per_90': 0.79,
#   'clean_sheets_per_90': 0.79},
#  {'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 192895,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': -1,
#   'cost_change_start_fall': 1,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Kieran',
#   'form': '0.0',
#   'id': 24,
#   'in_dreamteam': False,
#   'news': 'Season long loan to Real Sociedad',
#   'news_added': '2023-08-29T07:46:59.686803Z',
#   'now_cost': 44,
#   'photo': '192895.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Tierney',
#   'selected_by_percent': '0.1',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 1,
#   'team_code': 3,
#   'total_points': 0,
#   'transfers_in': 2665,
#   'transfers_in_event': 0,
#   'transfers_out': 28758,
#   'transfers_out_event': 27,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Tierney',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 670,
#   'influence_rank_type': 261,
#   'creativity_rank': 662,
#   'creativity_rank_type': 261,
#   'threat_rank': 635,
#   'threat_rank_type': 258,
#   'ict_index_rank': 673,
#   'ict_index_rank_type': 261,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 535,
#   'now_cost_rank_type': 99,
#   'form_rank': 577,
#   'form_rank_type': 238,
#   'points_per_game_rank': 682,
#   'points_per_game_rank_type': 259,
#   'selected_rank': 421,
#   'selected_rank_type': 166,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': 75,
#   'chance_of_playing_this_round': 50,
#   'code': 223723,
#   'cost_change_event': 0,
# ...
#   'now_cost_rank_type': 335,
#   'form_rank': 367,
#   'form_rank_type': 173,
#   'points_per_game_rank': 459,
#   'points_per_game_rank_type': 205,
#   'selected_rank': 750,
#   'selected_rank_type': 302,
#   'starts_per_90': 0.0,
#   'clean_sheets_per_90': 0.0},
#  {'chance_of_playing_next_round': 100,
#   'chance_of_playing_this_round': 100,
#   'code': 504750,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Justin',
#   'form': '0.0',
#   'id': 751,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': '2024-01-03T01:00:13.347562Z',
#   'now_cost': 40,
#   'photo': '504750.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Hubner',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 3703,
#   'transfers_in_event': 276,
#   'transfers_out': 2208,
#   'transfers_out_event': 207,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Hubner',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 620,
#   'influence_rank_type': 233,
#   'creativity_rank': 607,
#   'creativity_rank_type': 232,
#   'threat_rank': 570,
#   'threat_rank_type': 222,
#   'ict_index_rank': 624,
#   'ict_index_rank_type': 233,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 747,
#   'now_cost_rank_type': 217,
#   'form_rank': 496,
#   'form_rank_type': 188,
#   'points_per_game_rank': 631,
#   'points_per_game_rank_type': 229,
#   'selected_rank': 582,
#   'selected_rank_type': 217,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 432712,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Owen',
#   'form': '0.0',
#   'id': 769,
#   'in_dreamteam': False,
#   'news': 'On loan to Kidderminster Harriers until the end of the season',
#   'news_added': '2024-01-08T09:35:58.050059Z',
#   'now_cost': 45,
#   'photo': '432712.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Hesketh',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 76,
#   'transfers_in_event': 0,
#   'transfers_out': 60,
#   'transfers_out_event': 2,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Hesketh',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 714,
#   'influence_rank_type': 278,
#   'creativity_rank': 709,
#   'creativity_rank_type': 279,
#   'threat_rank': 693,
#   'threat_rank_type': 271,
#   'ict_index_rank': 717,
#   'ict_index_rank_type': 279,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 409,
#   'now_cost_rank_type': 237,
#   'form_rank': 640,
#   'form_rank_type': 232,
#   'points_per_game_rank': 720,
#   'points_per_game_rank_type': 282,
#   'selected_rank': 824,
#   'selected_rank_type': 356,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 490095,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Ty',
#   'form': '0.0',
#   'id': 770,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '490095.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Barnett',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 564,
#   'transfers_in_event': 27,
#   'transfers_out': 339,
#   'transfers_out_event': 23,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Barnett',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 733,
#   'influence_rank_type': 293,
#   'creativity_rank': 727,
#   'creativity_rank_type': 292,
#   'threat_rank': 715,
#   'threat_rank_type': 287,
#   'ict_index_rank': 736,
#   'ict_index_rank_type': 294,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 441,
#   'now_cost_rank_type': 258,
#   'form_rank': 661,
#   'form_rank_type': 249,
#   'points_per_game_rank': 736,
#   'points_per_game_rank_type': 295,
#   'selected_rank': 758,
#   'selected_rank_type': 306,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 449133,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Harvey',
#   'form': '0.0',
#   'id': 787,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 45,
#   'photo': '449133.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Griffiths',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 285,
#   'transfers_in_event': 30,
#   'transfers_out': 129,
#   'transfers_out_event': 16,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Griffiths',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 719,
#   'influence_rank_type': 282,
#   'creativity_rank': 714,
#   'creativity_rank_type': 283,
#   'threat_rank': 699,
#   'threat_rank_type': 275,
#   'ict_index_rank': 722,
#   'ict_index_rank_type': 283,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 418,
#   'now_cost_rank_type': 241,
#   'form_rank': 645,
#   'form_rank_type': 236,
#   'points_per_game_rank': 725,
#   'points_per_game_rank_type': 286,
#   'selected_rank': 786,
#   'selected_rank_type': 328,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': 0,
#   'chance_of_playing_this_round': 0,
#   'code': 501837,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Yerson',
#   'form': '0.0',
#   'id': 788,
#   'in_dreamteam': False,
#   'news': 'On loan to Villarreal until the end of the season',
#   'news_added': '2024-01-25T09:07:40.695577Z',
#   'now_cost': 40,
#   'photo': '501837.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Mosquera',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'u',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 19,
#   'transfers_in_event': 0,
#   'transfers_out': 9,
#   'transfers_out_event': 0,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Mosquera',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 617,
#   'influence_rank_type': 231,
#   'creativity_rank': 604,
#   'creativity_rank_type': 230,
#   'threat_rank': 567,
#   'threat_rank_type': 220,
#   'ict_index_rank': 621,
#   'ict_index_rank_type': 231,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 743,
#   'now_cost_rank_type': 214,
#   'form_rank': 493,
#   'form_rank_type': 186,
#   'points_per_game_rank': 628,
#   'points_per_game_rank_type': 227,
#   'selected_rank': 831,
#   'selected_rank_type': 268,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 550833,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 3,
#   'ep_next': '0.0',
#   'ep_this': '0.0',
#   'event_points': 0,
#   'first_name': 'Noha',
#   'form': '0.0',
#   'id': 800,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 50,
#   'photo': '550833.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Lemina',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 1078,
#   'transfers_in_event': 160,
#   'transfers_out': 624,
#   'transfers_out_event': 144,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'N.Lemina',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 814,
#   'influence_rank_type': 352,
#   'creativity_rank': 812,
#   'creativity_rank_type': 352,
#   'threat_rank': 810,
#   'threat_rank_type': 352,
#   'ict_index_rank': 814,
#   'ict_index_rank_type': 352,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 215,
#   'now_cost_rank_type': 136,
#   'form_rank': 790,
#   'form_rank_type': 338,
#   'points_per_game_rank': 813,
#   'points_per_game_rank_type': 352,
#   'selected_rank': 728,
#   'selected_rank_type': 291,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0},
#  {'chance_of_playing_next_round': None,
#   'chance_of_playing_this_round': None,
#   'code': 613467,
#   'cost_change_event': 0,
#   'cost_change_event_fall': 0,
#   'cost_change_start': 0,
#   'cost_change_start_fall': 0,
#   'dreamteam_count': 0,
#   'element_type': 2,
#   'ep_next': '1.4',
#   'ep_this': '1.4',
#   'event_points': 0,
#   'first_name': 'Wesley',
#   'form': '0.0',
#   'id': 832,
#   'in_dreamteam': False,
#   'news': '',
#   'news_added': None,
#   'now_cost': 40,
#   'photo': '613467.jpg',
#   'points_per_game': '0.0',
#   'second_name': 'Okoduwa',
#   'selected_by_percent': '0.0',
#   'special': False,
#   'squad_number': None,
#   'status': 'a',
#   'team': 20,
#   'team_code': 39,
#   'total_points': 0,
#   'transfers_in': 121,
#   'transfers_in_event': 121,
#   'transfers_out': 10,
#   'transfers_out_event': 10,
#   'value_form': '0.0',
#   'value_season': '0.0',
#   'web_name': 'Okoduwa',
#   'minutes': 0,
#   'goals_scored': 0,
#   'assists': 0,
#   'clean_sheets': 0,
#   'goals_conceded': 0,
#   'own_goals': 0,
#   'penalties_saved': 0,
#   'penalties_missed': 0,
#   'yellow_cards': 0,
#   'red_cards': 0,
#   'saves': 0,
#   'bonus': 0,
#   'bps': 0,
#   'influence': '0.0',
#   'creativity': '0.0',
#   'threat': '0.0',
#   'ict_index': '0.0',
#   'starts': 0,
#   'expected_goals': '0.00',
#   'expected_assists': '0.00',
#   'expected_goal_involvements': '0.00',
#   'expected_goals_conceded': '0.00',
#   'influence_rank': 646,
#   'influence_rank_type': 254,
#   'creativity_rank': 633,
#   'creativity_rank_type': 253,
#   'threat_rank': 597,
#   'threat_rank_type': 244,
#   'ict_index_rank': 650,
#   'ict_index_rank_type': 254,
#   'corners_and_indirect_freekicks_order': None,
#   'corners_and_indirect_freekicks_text': '',
#   'direct_freekicks_order': None,
#   'direct_freekicks_text': '',
#   'penalties_order': None,
#   'penalties_text': '',
#   'expected_goals_per_90': 0,
#   'saves_per_90': 0,
#   'expected_assists_per_90': 0,
#   'expected_goal_involvements_per_90': 0,
#   'expected_goals_conceded_per_90': 0,
#   'goals_conceded_per_90': 0,
#   'now_cost_rank': 774,
#   'now_cost_rank_type': 239,
#   'form_rank': 522,
#   'form_rank_type': 209,
#   'points_per_game_rank': 657,
#   'points_per_game_rank_type': 250,
#   'selected_rank': 792,
#   'selected_rank_type': 263,
#   'starts_per_90': 0,
#   'clean_sheets_per_90': 0}]
